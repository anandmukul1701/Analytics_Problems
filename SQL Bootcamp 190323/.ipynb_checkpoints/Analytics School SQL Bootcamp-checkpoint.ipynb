# %% [markdown]
# <img src="https://user-images.githubusercontent.com/60250009/226021131-b8da7976-ae42-4d47-b744-c598d640875b.png" alt="Drawing" style="width: 1000px;"/>[Follow Us](https://www.linkedin.com/company/analytics-school/?viewAsMember=true)
#
# ### 🤝 Connect with us:
#
# <a href="https://www.linkedin.com/company/analytics-school"><img align="left" src="https://raw.githubusercontent.com/yushi1007/yushi1007/main/images/linkedin.svg" alt="Abalytics school | LinkedIn" width="50px"/></a>
#
# <a href="https://www.instagram.com/analytics_school/"><img align="left" src="https://raw.githubusercontent.com/yushi1007/yushi1007/main/images/instagram.svg" alt="Abalytics school | Instagram" width="50px"/></a>
#
# <a href="https://www.facebook.com/Analyticschool"><img align="left" src="https://user-images.githubusercontent.com/127306551/224540351-3b052edc-6ccc-4343-be90-75c4d38e0e1c.png" alt="Abalytics school | Facebook" width="50px"/></a>
# </br></br></br>
# ### 🤝 Join our Community:
# <a href="https://analytics-school.slack.com/"><img align="left" src="https://user-images.githubusercontent.com/127306551/224540407-8692c77f-78b4-4479-8d4d-6d066ffe0777.png" alt="Abalytics school | Slack" width="50px"/></a>
#
# <a href="https://chat.whatsapp.com/FF0RTK21U5l6DWfKfTuIjx/"><img align="left" src="https://user-images.githubusercontent.com/60250009/226002802-0021a714-c7b3-4952-8d4c-190f162036bb.png" alt="Abalytics school | Slack" width="60px"/></a>
#
# <a href="https://t.me/+zSGh-MeXzUBkNWU1/"><img align="left" src="https://user-images.githubusercontent.com/60250009/226004563-f6cc568b-bd2c-4db7-b25c-59f3df6b3778.png" alt="Abalytics school | Slack" width="50px"/></a>
# </br>

# %%
# %load_ext sql
# %reload_ext sql
import pymysql
import urllib.parse

# %%
password = urllib.parse.quote_plus('Mukul@ms30') ## Input your password

# %sql mysql+pymysql://root:{password}@localhost/employees

# %config SqlMagic.displaycon = False

# %% [markdown]
# # SQL
# SQL (Structured Query Language) is a standard programming language for managing and manipulating relational databases. It is used to insert, update, and retrieve data from a database, as well as to manage database structure and user access control. SQL is supported by many relational database management systems including MySQL, PostgreSQL, and Microsoft SQL Server.

# %% [markdown]
# # RDBMS
# A Relational Database Management System (RDMS) is a software system that is used to manage and organize data stored in relational databases. It allows you to store and retrieve data by creating tables, defining relationships between tables, and using SQL to manipulate and query the data.
#
# For example, consider a simple database for an ecommerce. And see how the storing data with RDBMS and without RDBMS changes
#
# By using relationships between the tables, the RDMS can help you to keep track
#
# SQL is the most common language used to interact with relational databases.

# %% [markdown]
# ## Without RDBMS

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ## With RDBMS
# ![image.png](attachment:image.png)

# %% [markdown]
# # Lets start learning SQL:

# %% [markdown]
# <img src="https://user-images.githubusercontent.com/60250009/226021932-31637379-0ae1-4167-b39e-91125dd2a1f3.png" alt="Drawing" style="width: 700px;"/>

# %% [markdown]
# ## **`SELECT`** & **`FROM`**
#
# The **`SELECT`** statement in SQL is used to query a database and retrieve data from one or more tables. The basic syntax of a SELECT statement is as follows:
#
# The **`FROM`** statement specifies the table or tables from which to retrieve data.
#
# **Notes:**
# - Don’t try to apply filtering in the Select statement.
# - We can select multiple columns in the SELECT statement however we can’t select from multiple tables without using joins, which will come in the later sections.

# %%
# SELECT column1, column2, ...
# FROM table_name;

# %% [markdown]
# ## Schema

# %% [markdown]
# <img src="https://user-images.githubusercontent.com/60250009/226022487-e6dbd30b-d373-4662-b893-3f6c22e2fe7e.png" alt="Drawing" style="width: 800px;"/>

# %% [markdown]
# ## **`Limit`** Clause
# - The **`LIMIT`** clause is used to limit the number of rows returned by a query. It is particularly useful when working with large tables that contain many rows, as it allows you to retrieve only a subset of the rows at a time.
#
# - The **`LIMIT`** clause is typically used at the end of a SELECT statement and has two parameters: the first parameter specifies the starting point of the limit, and the second parameter specifies the number of rows to return.

# %%
# %%sql
#
# SELECT emp_no, birth_date, first_name, last_name
# FROM employees
#
# limit 10
# ;
# Out:
# 10 rows affected.
# [(10001, datetime.date(1953, 9, 2), 'Georgi', 'Facello'),
#  (10002, datetime.date(1964, 6, 2), 'Bezalel', 'Simmel'),
#  (10003, datetime.date(1959, 12, 3), 'Parto', 'Bamford'),
#  (10004, datetime.date(1954, 5, 1), 'Chirstian', 'Koblick'),
#  (10005, datetime.date(1955, 1, 21), 'Kyoichi', 'Maliniak'),
#  (10006, datetime.date(1953, 4, 20), 'Anneke', 'Preusig'),
#  (10007, datetime.date(1957, 5, 23), 'Tzvetan', 'Zielinski'),
#  (10008, datetime.date(1958, 2, 19), 'Saniya', 'Kalloufi'),
#  (10009, datetime.date(1952, 4, 19), 'Sumant', 'Peac'),
#  (10010, datetime.date(1963, 6, 1), 'Duangkaew', 'Piveteau')]

# %% [markdown]
# **Question**
# - select `emp_no`, `birth_date`, `first_name`, `last_name`, `gender`, `hire_date` columns from employees table

# %%
# %%sql
#
# SELECT emp_no, birth_date, first_name, last_name, gender, hire_date
# FROM employees
# limit 10
# ;
# Out:
# 10 rows affected.
# [(10001, datetime.date(1953, 9, 2), 'Georgi', 'Facello', 'M', datetime.date(1986, 6, 26)),
#  (10002, datetime.date(1964, 6, 2), 'Bezalel', 'Simmel', 'F', datetime.date(1985, 11, 21)),
#  (10003, datetime.date(1959, 12, 3), 'Parto', 'Bamford', 'M', datetime.date(1986, 8, 28)),
#  (10004, datetime.date(1954, 5, 1), 'Chirstian', 'Koblick', 'M', datetime.date(1986, 12, 1)),
#  (10005, datetime.date(1955, 1, 21), 'Kyoichi', 'Maliniak', 'M', datetime.date(1989, 9, 12)),
#  (10006, datetime.date(1953, 4, 20), 'Anneke', 'Preusig', 'F', datetime.date(1989, 6, 2)),
#  (10007, datetime.date(1957, 5, 23), 'Tzvetan', 'Zielinski', 'F', datetime.date(1989, 2, 10)),
#  (10008, datetime.date(1958, 2, 19), 'Saniya', 'Kalloufi', 'M', datetime.date(1994, 9, 15)),
#  (10009, datetime.date(1952, 4, 19), 'Sumant', 'Peac', 'F', datetime.date(1985, 2, 18)),
#  (10010, datetime.date(1963, 6, 1), 'Duangkaew', 'Piveteau', 'F', datetime.date(1989, 8, 24))]

# %% [markdown]
# **If you notice we've selected all the columns of Employees table in the above query, But that's too much typing, Is there any other way??**

# %%
# %%sql
# # For example, to retrieve all columns from the employees table, you can use the following SQL statement:
# SELECT *
# FROM employees
# limit 10
# ;
# Out:
# 10 rows affected.
# [(10001, datetime.date(1953, 9, 2), 'Georgi', 'Facello', 'M', datetime.date(1986, 6, 26)),
#  (10002, datetime.date(1964, 6, 2), 'Bezalel', 'Simmel', 'F', datetime.date(1985, 11, 21)),
#  (10003, datetime.date(1959, 12, 3), 'Parto', 'Bamford', 'M', datetime.date(1986, 8, 28)),
#  (10004, datetime.date(1954, 5, 1), 'Chirstian', 'Koblick', 'M', datetime.date(1986, 12, 1)),
#  (10005, datetime.date(1955, 1, 21), 'Kyoichi', 'Maliniak', 'M', datetime.date(1989, 9, 12)),
#  (10006, datetime.date(1953, 4, 20), 'Anneke', 'Preusig', 'F', datetime.date(1989, 6, 2)),
#  (10007, datetime.date(1957, 5, 23), 'Tzvetan', 'Zielinski', 'F', datetime.date(1989, 2, 10)),
#  (10008, datetime.date(1958, 2, 19), 'Saniya', 'Kalloufi', 'M', datetime.date(1994, 9, 15)),
#  (10009, datetime.date(1952, 4, 19), 'Sumant', 'Peac', 'F', datetime.date(1985, 2, 18)),
#  (10010, datetime.date(1963, 6, 1), 'Duangkaew', 'Piveteau', 'F', datetime.date(1989, 8, 24))]

# %% [markdown]
# **`Select *` Specifies that we want to select all the columns from the given table**

# %% [markdown]
# ## **`SELECT DISTINCT`**:
# The **`SELECT DISTINCT`** statement is used to retrieve only unique values from a column in a table. This can be useful when you want to eliminate duplicates in your query results.
#
# For example, to retrieve only the distinct values of the gender column from the employees table, you can use the following SQL statement:
#
# **NOTE:**
# - If you include multiple columns, your result set will return all distinct combinations of values across those columns

# %%
# %%sql
#
# SELECT DISTINCT gender
# FROM employees
# limit 10
# ;
# Out:
# 2 rows affected.
# [('M',), ('F',)]

# %% [markdown]
# **Question**
# - select distinct `first_name` from the employees table

# %%
# %%sql
#
# SELECT DISTINCT first_name
# FROM employees
# limit 10
# ;
# Out:
# 10 rows affected.
# [('Georgi',),
#  ('Bezalel',),
#  ('Parto',),
#  ('Chirstian',),
#  ('Kyoichi',),
#  ('Anneke',),
#  ('Tzvetan',),
#  ('Saniya',),
#  ('Sumant',),
#  ('Duangkaew',)]

# %% [markdown]
# **Question**
# - Select distinct year of birth from the `employees` table
#
# **Hint**
# - **`"YEAR"`** is a function in MySQL which extracts year from a given date, Eg: YEAR('1953-09-02') = 1953

# %%
# %%sql
#
# select distinct year(birth_date)
# from employees
#
# limit 10
# ;
# Out:
# 10 rows affected.
# [(1953,),
#  (1964,),
#  (1959,),
#  (1954,),
#  (1955,),
#  (1957,),
#  (1958,),
#  (1952,),
#  (1963,),
#  (1960,)]

# %% [markdown]
# **Question**
# - Select distinct `year of birth` & `gender` from the employees table (Don't use limit here to see full results)
#
# **Hint**
# - **`"YEAR"`** is a function in MySQL which extracts year from a given date, Eg: YEAR('1953-09-02') = 1953

# %%
# %%sql
#
# select distinct year(birth_date), gender
# from employees
# ;
# Out:
# 28 rows affected.
# [(1953, 'M'),
#  (1964, 'F'),
#  (1959, 'M'),
#  (1954, 'M'),
#  (1955, 'M'),
#  (1953, 'F'),
#  (1957, 'F'),
#  (1958, 'M'),
#  (1952, 'F'),
#  (1963, 'F'),
#  (1960, 'M'),
#  (1963, 'M'),
#  (1956, 'M'),
#  (1961, 'M'),
#  (1958, 'F'),
#  (1954, 'F'),
#  (1952, 'M'),
#  (1962, 'F'),
#  (1960, 'F'),
#  (1962, 'M'),
#  (1959, 'F'),
#  (1956, 'F'),
#  (1961, 'F'),
#  (1957, 'M'),
#  (1955, 'F'),
#  (1964, 'M'),
#  (1965, 'M'),
#  (1965, 'F')]

# %% [markdown]
# ## **`WHERE`**:
# The **`WHERE`** statement is used to filter data based on a specified condition. It is used to extract only the records that meet the condition.
#
# For example, to retrieve all columns from the `employees` table where the `gender` column is equal to `"M"`, you can use the following SQL statement:

# %% [markdown]
# ## Usecases of Where Clause
# - Pulling records before or after a date , or between two dates
# - Limiting your result set to include only transactions above a certain payment amount
# - Filtering your result set to just records related to certain employee , or to certain gender

# %%
# %%sql
# SELECT * FROM employees
# WHERE gender = 'M'
# limit 10
# ;
# Out:
# 10 rows affected.
# [(10001, datetime.date(1953, 9, 2), 'Georgi', 'Facello', 'M', datetime.date(1986, 6, 26)),
#  (10003, datetime.date(1959, 12, 3), 'Parto', 'Bamford', 'M', datetime.date(1986, 8, 28)),
#  (10004, datetime.date(1954, 5, 1), 'Chirstian', 'Koblick', 'M', datetime.date(1986, 12, 1)),
#  (10005, datetime.date(1955, 1, 21), 'Kyoichi', 'Maliniak', 'M', datetime.date(1989, 9, 12)),
#  (10008, datetime.date(1958, 2, 19), 'Saniya', 'Kalloufi', 'M', datetime.date(1994, 9, 15)),
#  (10012, datetime.date(1960, 10, 4), 'Patricio', 'Bridgland', 'M', datetime.date(1992, 12, 18)),
#  (10013, datetime.date(1963, 6, 7), 'Eberhardt', 'Terkki', 'M', datetime.date(1985, 10, 20)),
#  (10014, datetime.date(1956, 2, 12), 'Berni', 'Genin', 'M', datetime.date(1987, 3, 11)),
#  (10015, datetime.date(1959, 8, 19), 'Guoxiang', 'Nooteboom', 'M', datetime.date(1987, 7, 2)),
#  (10016, datetime.date(1961, 5, 2), 'Kazuhito', 'Cappelletti', 'M', datetime.date(1995, 1, 27))]

# %% [markdown]
# **Question**
# - Select all the female employees
# - select all the employees with first_name = Saniya

# %%
# %%sql
#
# SELECT * FROM employees
# WHERE gender = 'F'
# limit 10
# ;
# Out:
# 10 rows affected.
# [(10002, datetime.date(1964, 6, 2), 'Bezalel', 'Simmel', 'F', datetime.date(1985, 11, 21)),
#  (10006, datetime.date(1953, 4, 20), 'Anneke', 'Preusig', 'F', datetime.date(1989, 6, 2)),
#  (10007, datetime.date(1957, 5, 23), 'Tzvetan', 'Zielinski', 'F', datetime.date(1989, 2, 10)),
#  (10009, datetime.date(1952, 4, 19), 'Sumant', 'Peac', 'F', datetime.date(1985, 2, 18)),
#  (10010, datetime.date(1963, 6, 1), 'Duangkaew', 'Piveteau', 'F', datetime.date(1989, 8, 24)),
#  (10011, datetime.date(1953, 11, 7), 'Mary', 'Sluis', 'F', datetime.date(1990, 1, 22)),
#  (10017, datetime.date(1958, 7, 6), 'Cristinel', 'Bouloucos', 'F', datetime.date(1993, 8, 3)),
#  (10018, datetime.date(1954, 6, 19), 'Kazuhide', 'Peha', 'F', datetime.date(1987, 4, 3)),
#  (10023, datetime.date(1953, 9, 29), 'Bojan', 'Montemayor', 'F', datetime.date(1989, 12, 17)),
#  (10024, datetime.date(1958, 9, 5), 'Suzette', 'Pettey', 'F', datetime.date(1997, 5, 19))]

# %%
# %%sql
#
# SELECT * FROM employees
# WHERE first_name = 'Saniya'
# limit 10
# ;
# Out:
# 10 rows affected.
# [(10008, datetime.date(1958, 2, 19), 'Saniya', 'Kalloufi', 'M', datetime.date(1994, 9, 15)),
#  (11208, datetime.date(1952, 5, 29), 'Saniya', 'Valtorta', 'F', datetime.date(1988, 8, 26)),
#  (12582, datetime.date(1961, 1, 23), 'Saniya', 'Herath', 'F', datetime.date(1987, 2, 7)),
#  (12796, datetime.date(1954, 5, 2), 'Saniya', 'Stanfel', 'M', datetime.date(1992, 5, 24)),
#  (13802, datetime.date(1964, 1, 8), 'Saniya', 'Benzmuller', 'F', datetime.date(1990, 10, 27)),
#  (14372, datetime.date(1952, 4, 15), 'Saniya', 'Srimani', 'F', datetime.date(1988, 1, 23)),
#  (15351, datetime.date(1958, 2, 8), 'Saniya', 'Biros', 'M', datetime.date(1988, 1, 23)),
#  (16644, datetime.date(1952, 5, 20), 'Saniya', 'Yoshimura', 'M', datetime.date(1991, 12, 13)),
#  (16727, datetime.date(1963, 11, 5), 'Saniya', 'Codenie', 'M', datetime.date(1987, 9, 24)),
#  (17171, datetime.date(1957, 12, 24), 'Saniya', 'Litzkow', 'M', datetime.date(1990, 7, 5))]

# %% [markdown]
# ## Comparison operators:
# Comparison operators are used to compare two values and return a boolean result (TRUE or FALSE). There are several comparison operators in SQL, including:

# %% [markdown]
# <img src="https://user-images.githubusercontent.com/60250009/226023459-b45bd1cc-80fa-49cf-8600-1d24f87a4973.png" alt="Drawing" style="width: 400px;"/>

# %% [markdown]
# ## **`AND`** Operator:
# The **`AND`** operator is used to combine two or more conditions in a **`WHERE`** clause. It returns true if all of the conditions are true, and false if any of the conditions are false.
#
#
# For example, to retrieve all rows from the employees table where
# - the gender column is equal to "M" and
# - the birth_date column is greater than or equal to '1980-01-01'
#
# you can use the following SQL statement with the AND operator:

# %% [markdown]
# - Select all the female employees with Year of birth > 1960

# %%
# %%sql
#
# SELECT * FROM employees
# WHERE gender = 'F'
# AND YEAR(birth_date) > 1960
# limit 10
# ;
# Out:
# 10 rows affected.
# [(10002, datetime.date(1964, 6, 2), 'Bezalel', 'Simmel', 'F', datetime.date(1985, 11, 21)),
#  (10010, datetime.date(1963, 6, 1), 'Duangkaew', 'Piveteau', 'F', datetime.date(1989, 8, 24)),
#  (10027, datetime.date(1962, 7, 10), 'Divier', 'Reistad', 'F', datetime.date(1989, 7, 7)),
#  (10044, datetime.date(1961, 9, 21), 'Mingsen', 'Casley', 'F', datetime.date(1994, 5, 21)),
#  (10049, datetime.date(1961, 4, 24), 'Basil', 'Tramer', 'F', datetime.date(1992, 5, 4)),
#  (10056, datetime.date(1961, 9, 1), 'Brendon', 'Bernini', 'F', datetime.date(1990, 2, 1)),
#  (10079, datetime.date(1961, 10, 5), 'Kshitij', 'Gils', 'F', datetime.date(1986, 3, 27)),
#  (10089, datetime.date(1963, 3, 21), 'Sudharsan', 'Flasterstein', 'F', datetime.date(1986, 8, 12)),
#  (10092, datetime.date(1964, 10, 18), 'Valdiodio', 'Niizuma', 'F', datetime.date(1989, 9, 22)),
#  (10098, datetime.date(1961, 9, 23), 'Sreekrishna', 'Servieres', 'F', datetime.date(1985, 5, 13))]

# %%
# %%sql
#
# SELECT * FROM employees
# WHERE gender = 'M'
# AND birth_date >= '1960-01-01'
# limit 10
# ;
# Out:
# 10 rows affected.
# [(10012, datetime.date(1960, 10, 4), 'Patricio', 'Bridgland', 'M', datetime.date(1992, 12, 18)),
#  (10013, datetime.date(1963, 6, 7), 'Eberhardt', 'Terkki', 'M', datetime.date(1985, 10, 20)),
#  (10016, datetime.date(1961, 5, 2), 'Kazuhito', 'Cappelletti', 'M', datetime.date(1995, 1, 27)),
#  (10021, datetime.date(1960, 2, 20), 'Ramzi', 'Erde', 'M', datetime.date(1988, 2, 10)),
#  (10028, datetime.date(1963, 11, 26), 'Domenick', 'Tempesti', 'M', datetime.date(1991, 10, 22)),
#  (10034, datetime.date(1962, 12, 29), 'Bader', 'Swan', 'M', datetime.date(1988, 9, 21)),
#  (10037, datetime.date(1963, 7, 22), 'Pradeep', 'Makrucki', 'M', datetime.date(1990, 12, 5)),
#  (10038, datetime.date(1960, 7, 20), 'Huan', 'Lortz', 'M', datetime.date(1989, 9, 20)),
#  (10043, datetime.date(1960, 9, 19), 'Yishay', 'Tzvieli', 'M', datetime.date(1990, 10, 20)),
#  (10046, datetime.date(1960, 7, 23), 'Lucien', 'Rosenbaum', 'M', datetime.date(1992, 6, 20))]

# %% [markdown]
# ## **`OR`** Operator:
# The **`OR`** operator is used to combine two or more conditions in a **`WHERE`** clause. It returns true if any of the conditions are true, and false if all of the conditions are false.
#
#
# For example,
# to retrieve all rows from the employees table where
# - the birth_date column is equal to '1964-06-02' `OR`
# - the first_name column is equal to "Lech"
#
# you can use the following SQL statement with the OR operator:

# %%
# %%sql
#
# SELECT * FROM employees
# WHERE first_name = 'Lech' OR
# birth_date = '1964-06-02'
#
# limit 10
# ;
# Out:
# 10 rows affected.
# [(10002, datetime.date(1964, 6, 2), 'Bezalel', 'Simmel', 'F', datetime.date(1985, 11, 21)),
#  (10762, datetime.date(1965, 1, 19), 'Lech', 'Himler', 'M', datetime.date(1992, 1, 21)),
#  (11511, datetime.date(1964, 6, 2), 'Arlette', 'Mikschl', 'M', datetime.date(1991, 9, 6)),
#  (14603, datetime.date(1954, 11, 13), 'Lech', 'Marquardt', 'M', datetime.date(1986, 1, 19)),
#  (19918, datetime.date(1961, 11, 22), 'Lech', 'Goodrum', 'M', datetime.date(1992, 11, 18)),
#  (20735, datetime.date(1964, 6, 2), 'Tetsushi', 'Stassinopoulos', 'F', datetime.date(1985, 5, 14)),
#  (20773, datetime.date(1964, 6, 2), 'Takahiro', 'Miyakawa', 'F', datetime.date(1989, 12, 13)),
#  (21109, datetime.date(1953, 9, 28), 'Lech', 'Chenoweth', 'F', datetime.date(1988, 10, 6)),
#  (21792, datetime.date(1962, 12, 7), 'Lech', 'Rosar', 'M', datetime.date(1987, 4, 6)),
#  (21994, datetime.date(1954, 5, 1), 'Lech', 'Babb', 'M', datetime.date(1986, 11, 9))]

# %% [markdown]
# **Question**
# - Find all the rows where either `first_name` is 'Lech' `OR` `gender` is Female

# %%
# %%sql
#
# SELECT * FROM employees
# WHERE first_name = 'Lech' OR
# gender = 'F'
#
#
# limit 10
# ;
# Out:
# 10 rows affected.
# [(10002, datetime.date(1964, 6, 2), 'Bezalel', 'Simmel', 'F', datetime.date(1985, 11, 21)),
#  (10006, datetime.date(1953, 4, 20), 'Anneke', 'Preusig', 'F', datetime.date(1989, 6, 2)),
#  (10007, datetime.date(1957, 5, 23), 'Tzvetan', 'Zielinski', 'F', datetime.date(1989, 2, 10)),
#  (10009, datetime.date(1952, 4, 19), 'Sumant', 'Peac', 'F', datetime.date(1985, 2, 18)),
#  (10010, datetime.date(1963, 6, 1), 'Duangkaew', 'Piveteau', 'F', datetime.date(1989, 8, 24)),
#  (10011, datetime.date(1953, 11, 7), 'Mary', 'Sluis', 'F', datetime.date(1990, 1, 22)),
#  (10017, datetime.date(1958, 7, 6), 'Cristinel', 'Bouloucos', 'F', datetime.date(1993, 8, 3)),
#  (10018, datetime.date(1954, 6, 19), 'Kazuhide', 'Peha', 'F', datetime.date(1987, 4, 3)),
#  (10023, datetime.date(1953, 9, 29), 'Bojan', 'Montemayor', 'F', datetime.date(1989, 12, 17)),
#  (10024, datetime.date(1958, 9, 5), 'Suzette', 'Pettey', 'F', datetime.date(1997, 5, 19))]

# %% [markdown]
# **Question**
# - Find all the rows where either `gender` is Female `OR` Year of Hire is greater than 1990

# %%
# %%sql
#
# SELECT * FROM employees
# WHERE year(hire_date) > 1990 OR
# gender = 'F'
#
#
# limit 10
# ;
# Out:
# 10 rows affected.
# [(10002, datetime.date(1964, 6, 2), 'Bezalel', 'Simmel', 'F', datetime.date(1985, 11, 21)),
#  (10006, datetime.date(1953, 4, 20), 'Anneke', 'Preusig', 'F', datetime.date(1989, 6, 2)),
#  (10007, datetime.date(1957, 5, 23), 'Tzvetan', 'Zielinski', 'F', datetime.date(1989, 2, 10)),
#  (10008, datetime.date(1958, 2, 19), 'Saniya', 'Kalloufi', 'M', datetime.date(1994, 9, 15)),
#  (10009, datetime.date(1952, 4, 19), 'Sumant', 'Peac', 'F', datetime.date(1985, 2, 18)),
#  (10010, datetime.date(1963, 6, 1), 'Duangkaew', 'Piveteau', 'F', datetime.date(1989, 8, 24)),
#  (10011, datetime.date(1953, 11, 7), 'Mary', 'Sluis', 'F', datetime.date(1990, 1, 22)),
#  (10012, datetime.date(1960, 10, 4), 'Patricio', 'Bridgland', 'M', datetime.date(1992, 12, 18)),
#  (10016, datetime.date(1961, 5, 2), 'Kazuhito', 'Cappelletti', 'M', datetime.date(1995, 1, 27)),
#  (10017, datetime.date(1958, 7, 6), 'Cristinel', 'Bouloucos', 'F', datetime.date(1993, 8, 3))]

# %% [markdown]
# **Question**
# - Find all the rows where `first_name` is either 'Lech' or 'Bezalel'

# %%
# %%sql
#
# SELECT * FROM employees
# WHERE first_name = 'Lech' OR first_name = 'Bezalel'
#
#
# limit 10
# ;
# Out:
# 10 rows affected.
# [(10002, datetime.date(1964, 6, 2), 'Bezalel', 'Simmel', 'F', datetime.date(1985, 11, 21)),
#  (10630, datetime.date(1954, 8, 10), 'Bezalel', 'Katzenelson', 'F', datetime.date(1993, 6, 26)),
#  (10762, datetime.date(1965, 1, 19), 'Lech', 'Himler', 'M', datetime.date(1992, 1, 21)),
#  (11251, datetime.date(1955, 10, 16), 'Bezalel', 'Chinal', 'M', datetime.date(1985, 11, 26)),
#  (12787, datetime.date(1958, 6, 25), 'Bezalel', 'Shanbhogue', 'M', datetime.date(1986, 12, 16)),
#  (13594, datetime.date(1963, 12, 24), 'Bezalel', 'Spelt', 'M', datetime.date(1993, 11, 23)),
#  (13634, datetime.date(1962, 5, 18), 'Bezalel', 'Biros', 'M', datetime.date(1992, 1, 3)),
#  (13743, datetime.date(1956, 6, 9), 'Bezalel', 'Ruemmler', 'M', datetime.date(1994, 1, 23)),
#  (14603, datetime.date(1954, 11, 13), 'Lech', 'Marquardt', 'M', datetime.date(1986, 1, 19)),
#  (16413, datetime.date(1960, 2, 28), 'Bezalel', 'Bahk', 'F', datetime.date(1986, 3, 28))]

# %% [markdown]
# ## **`IN`** Operator:
# The **`IN`** operator is used to specify a list of values to match against a column. It returns true if the value matches any of the values in the list, and false otherwise.
#
# For example,
# to retrieve all rows from the employees table where
# - the `first_name` column is either "Bezalel" or "Lech"
#
# you can use the following SQL statement with the IN operator:

# %%
# %%sql
#
# SELECT * FROM employees
# WHERE first_name in ('Lech','Bezalel','Mary')
#
# limit 10
# ;
# Out:
# 10 rows affected.
# [(10002, datetime.date(1964, 6, 2), 'Bezalel', 'Simmel', 'F', datetime.date(1985, 11, 21)),
#  (10011, datetime.date(1953, 11, 7), 'Mary', 'Sluis', 'F', datetime.date(1990, 1, 22)),
#  (10532, datetime.date(1959, 8, 31), 'Mary', 'Wossner', 'F', datetime.date(1986, 5, 18)),
#  (10630, datetime.date(1954, 8, 10), 'Bezalel', 'Katzenelson', 'F', datetime.date(1993, 6, 26)),
#  (10762, datetime.date(1965, 1, 19), 'Lech', 'Himler', 'M', datetime.date(1992, 1, 21)),
#  (11251, datetime.date(1955, 10, 16), 'Bezalel', 'Chinal', 'M', datetime.date(1985, 11, 26)),
#  (11821, datetime.date(1954, 10, 18), 'Mary', 'Piazza', 'F', datetime.date(1995, 12, 13)),
#  (12334, datetime.date(1962, 3, 8), 'Mary', 'Ertl', 'F', datetime.date(1990, 3, 6)),
#  (12787, datetime.date(1958, 6, 25), 'Bezalel', 'Shanbhogue', 'M', datetime.date(1986, 12, 16)),
#  (13562, datetime.date(1960, 2, 15), 'Mary', 'Cooley', 'M', datetime.date(1986, 2, 24))]

# %% [markdown]
# ## **`LIKE`** Operator:
# The **`LIKE`** operator is used to match a pattern against a string column. It returns true if the pattern matches any part of the string, and false otherwise.
#
#
# For example,
# to retrieve all rows from the employees table where
# - the `first_name` column starts with "J",
#
#
# you can use the following SQL statement with the LIKE operator and wildcard character '%':

# %%
# %%sql
#
# SELECT * FROM employees
# WHERE first_name LIKE 'J%'
#
# limit 10
# ;
# Out:
# 10 rows affected.
# [(10032, datetime.date(1960, 8, 9), 'Jeong', 'Reistad', 'F', datetime.date(1990, 6, 20)),
#  (10088, datetime.date(1954, 2, 25), 'Jungsoon', 'Syrzycki', 'F', datetime.date(1988, 9, 2)),
#  (10096, datetime.date(1954, 9, 16), 'Jayson', 'Mandell', 'M', datetime.date(1990, 1, 14)),
#  (10113, datetime.date(1963, 11, 13), 'Jaewon', 'Syrzycki', 'M', datetime.date(1989, 12, 24)),
#  (10152, datetime.date(1954, 12, 1), 'Jaques', 'Munro', 'F', datetime.date(1986, 1, 27)),
#  (10164, datetime.date(1956, 1, 19), 'Jagoda', 'Braunmuhl', 'M', datetime.date(1985, 11, 12)),
#  (10194, datetime.date(1954, 1, 29), 'Josyula', 'Hofmeyr', 'F', datetime.date(1989, 5, 15)),
#  (10213, datetime.date(1964, 5, 24), 'Jackson', 'Kakkad', 'M', datetime.date(1992, 11, 6)),
#  (10337, datetime.date(1957, 12, 10), 'Jeong', 'Sadowsky', 'M', datetime.date(1995, 8, 6)),
#  (10381, datetime.date(1963, 3, 4), 'Jiong', 'Parfitt', 'M', datetime.date(1991, 12, 4))]

# %% [markdown]
# **Question**
# - Pull all the records where the `first_name` either starts with "J" or "B"

# %%
# %%sql
#
# SELECT * FROM employees
# WHERE first_name LIKE 'J%' OR first_name LIKE 'B%'
#
# limit 10
# ;
# Out:
# 10 rows affected.
# [(10002, datetime.date(1964, 6, 2), 'Bezalel', 'Simmel', 'F', datetime.date(1985, 11, 21)),
#  (10014, datetime.date(1956, 2, 12), 'Berni', 'Genin', 'M', datetime.date(1987, 3, 11)),
#  (10023, datetime.date(1953, 9, 29), 'Bojan', 'Montemayor', 'F', datetime.date(1989, 12, 17)),
#  (10032, datetime.date(1960, 8, 9), 'Jeong', 'Reistad', 'F', datetime.date(1990, 6, 20)),
#  (10034, datetime.date(1962, 12, 29), 'Bader', 'Swan', 'M', datetime.date(1988, 9, 21)),
#  (10049, datetime.date(1961, 4, 24), 'Basil', 'Tramer', 'F', datetime.date(1992, 5, 4)),
#  (10056, datetime.date(1961, 9, 1), 'Brendon', 'Bernini', 'F', datetime.date(1990, 2, 1)),
#  (10058, datetime.date(1954, 10, 1), 'Berhard', 'McFarlin', 'M', datetime.date(1987, 4, 13)),
#  (10060, datetime.date(1961, 10, 15), 'Breannda', 'Billingsley', 'M', datetime.date(1987, 11, 2)),
#  (10088, datetime.date(1954, 2, 25), 'Jungsoon', 'Syrzycki', 'F', datetime.date(1988, 9, 2))]

# %% [markdown]
# **Question**
# - Pull all the records where the `first_name` either starts with "J" or "B", And the year of birth is 1960

# %%
# %%sql
#
#
# SELECT * FROM employees
# WHERE (first_name LIKE 'J%' OR first_name LIKE 'B%')
# and year(birth_date) > 1960
#
# limit 10
# ;
# Out:
# 10 rows affected.
# [(10002, datetime.date(1964, 6, 2), 'Bezalel', 'Simmel', 'F', datetime.date(1985, 11, 21)),
#  (10034, datetime.date(1962, 12, 29), 'Bader', 'Swan', 'M', datetime.date(1988, 9, 21)),
#  (10049, datetime.date(1961, 4, 24), 'Basil', 'Tramer', 'F', datetime.date(1992, 5, 4)),
#  (10056, datetime.date(1961, 9, 1), 'Brendon', 'Bernini', 'F', datetime.date(1990, 2, 1)),
#  (10060, datetime.date(1961, 10, 15), 'Breannda', 'Billingsley', 'M', datetime.date(1987, 11, 2)),
#  (10113, datetime.date(1963, 11, 13), 'Jaewon', 'Syrzycki', 'M', datetime.date(1989, 12, 24)),
#  (10213, datetime.date(1964, 5, 24), 'Jackson', 'Kakkad', 'M', datetime.date(1992, 11, 6)),
#  (10246, datetime.date(1962, 6, 23), 'Basem', 'Teitelbaum', 'M', datetime.date(1987, 7, 12)),
#  (10270, datetime.date(1963, 1, 30), 'Bedir', 'Hartvigsen', 'F', datetime.date(1990, 4, 26)),
#  (10273, datetime.date(1962, 8, 29), 'Baocai', 'Lieblein', 'M', datetime.date(1985, 11, 6))]

# %% [markdown]
# ## Wildcard Operator:
# The Wildcard operators are used to match patterns in string values. There are two wildcard operators in SQL:
#
#
# - % (percent sign): Matches any string of zero or more characters.
# - _ (underscore): Matches any single character.
#
#
# For example, to retrieve all rows from the employees table where
# - the last_name column ends with "son",
#
# you can use the following SQL statement with the LIKE operator and the % wildcard character:

# %%
# %%sql
#
# SELECT * FROM employees WHERE last_name LIKE '%son'
#
# limit 10
# ;
# Out:
# 10 rows affected.
# [(10100, datetime.date(1953, 4, 21), 'Hironobu', 'Haraldson', 'F', datetime.date(1987, 9, 21)),
#  (10119, datetime.date(1960, 12, 1), 'Domenick', 'Peltason', 'M', datetime.date(1986, 3, 14)),
#  (10130, datetime.date(1955, 4, 27), 'Nishit', 'Casperson', 'M', datetime.date(1988, 6, 21)),
#  (10217, datetime.date(1954, 7, 7), 'Yongmin', 'Roison', 'F', datetime.date(1986, 5, 12)),
#  (10274, datetime.date(1957, 8, 23), 'Dmitri', 'Pearson', 'F', datetime.date(1991, 4, 21)),
#  (10434, datetime.date(1959, 7, 17), 'Dzung', 'Peltason', 'F', datetime.date(1995, 6, 27)),
#  (10493, datetime.date(1962, 1, 12), 'Maris', 'Haraldson', 'M', datetime.date(1992, 5, 16)),
#  (10548, datetime.date(1952, 6, 12), 'Ramalingam', 'Gunderson', 'M', datetime.date(1986, 5, 4)),
#  (10562, datetime.date(1963, 4, 17), 'Shuky', 'Pearson', 'M', datetime.date(1996, 7, 6)),
#  (10630, datetime.date(1954, 8, 10), 'Bezalel', 'Katzenelson', 'F', datetime.date(1993, 6, 26))]

# %%
# %%sql
#
# SELECT * FROM employees
# WHERE last_name LIKE 'L___'
#
# limit 10
# ;
# Out:
# 10 rows affected.
# [(10102, datetime.date(1959, 11, 4), 'Paraskevi', 'Luby', 'F', datetime.date(1994, 1, 26)),
#  (10275, datetime.date(1961, 10, 22), 'Marek', 'Luck', 'F', datetime.date(1987, 9, 8)),
#  (10384, datetime.date(1956, 8, 22), 'Feiyu', 'Luft', 'M', datetime.date(1986, 1, 16)),
#  (10426, datetime.date(1955, 12, 28), 'Arunas', 'Luce', 'F', datetime.date(1985, 7, 6)),
#  (10499, datetime.date(1953, 10, 4), 'Maik', 'Luft', 'F', datetime.date(1989, 11, 23)),
#  (10516, datetime.date(1960, 2, 20), 'Xiadong', 'Luga', 'M', datetime.date(1985, 10, 19)),
#  (10525, datetime.date(1963, 3, 29), 'Yuchang', 'Lunt', 'M', datetime.date(1990, 7, 8)),
#  (10810, datetime.date(1957, 10, 23), 'Lijie', 'Lunn', 'F', datetime.date(1994, 9, 7)),
#  (10907, datetime.date(1963, 9, 26), 'JiYoung', 'Luks', 'M', datetime.date(1988, 12, 25)),
#  (11018, datetime.date(1960, 8, 2), 'Berthier', 'Luby', 'F', datetime.date(1988, 7, 3))]

# %% [markdown]
# **Question**
# - Pull all the records where the 2nd last letter of `last_name` is 'o'
#
#
#
# **Hint**
# - use a combination of `%` and `_`

# %%
# %%sql
#
# select * from employees
# WHERE last_name LIKE '%O_'
#
# limit 10
# ;
# Out:
# 10 rows affected.
# [(10015, datetime.date(1959, 8, 19), 'Guoxiang', 'Nooteboom', 'M', datetime.date(1987, 7, 2)),
#  (10017, datetime.date(1958, 7, 6), 'Cristinel', 'Bouloucos', 'F', datetime.date(1993, 8, 3)),
#  (10023, datetime.date(1953, 9, 29), 'Bojan', 'Montemayor', 'F', datetime.date(1989, 12, 17)),
#  (10042, datetime.date(1956, 2, 26), 'Magy', 'Stamatiou', 'F', datetime.date(1993, 3, 21)),
#  (10067, datetime.date(1953, 1, 7), 'Claudi', 'Stavenow', 'M', datetime.date(1987, 3, 4)),
#  (10072, datetime.date(1952, 5, 15), 'Hironoby', 'Sidou', 'F', datetime.date(1988, 7, 21)),
#  (10095, datetime.date(1965, 1, 3), 'Hilari', 'Morton', 'M', datetime.date(1986, 7, 15)),
#  (10100, datetime.date(1953, 4, 21), 'Hironobu', 'Haraldson', 'F', datetime.date(1987, 9, 21)),
#  (10108, datetime.date(1952, 4, 7), 'Lunjin', 'Giveon', 'M', datetime.date(1986, 10, 2)),
#  (10119, datetime.date(1960, 12, 1), 'Domenick', 'Peltason', 'M', datetime.date(1986, 3, 14))]

# %% [markdown]
# ## Wildcard Examples

# %% [markdown]
# <img src="https://user-images.githubusercontent.com/60250009/226023994-9b843043-910b-48bf-883b-17fec1e95be5.png" alt="Drawing" style="width: 600px;"/>

# %% [markdown]
# ## Aggregate functions:
# Aggregate functions are functions in SQL that perform a calculation on a set of values and return a single value as the result. These functions are commonly used to perform calculations on groups of rows in a table.

# %%
# %%sql
#
# SELECT COUNT(*) FROM employees
#
# limit 10
# ;
# Out:
# 1 rows affected.
# [(300024,)]

# %%
# %%sql
#
# SELECT COUNT(emp_no) FROM employees
#
# limit 10
# ;
# Out:
# 1 rows affected.
# [(300024,)]

# %% [markdown]
# <div>
# <img src="https://user-images.githubusercontent.com/60250009/226026182-94b19355-b4f9-410b-8538-ad0139a13c6d.png" width="500"/>
# </div>

# %% [markdown]
# # **Alias**
# Aliases in SQL are temporary names given to tables or columns in a SQL statement. They are used to make SQL code more readable and concise. There are two types of aliases: table aliases and column aliases.
#
#
# A column alias in SQL is a temporary name given to a column in a SQL statement. It allows you to change the name of a column in the output of a query, or to give a specific name to a result of a calculation.
#
# The syntax for creating a column alias is as follows:
#
# **`
# SELECT column_name AS alias_name
# FROM table_name;
# `**
#
# In this syntax, "column_name" is the original name of the column, and "alias_name" is the temporary name given to the column. The AS keyword is optional and can be omitted.
#
# Here's an example of a SQL statement that uses a column alias:
#
# **`
# SELECT first_name, last_name, salary*12 AS annual_salary
# FROM employees;
# `**
#
# In this example, the column alias "annual_salary" is created by multiplying the "salary" column by 12. The output of the query will include the original columns "first_name" and "last_name" as well as the new column "annual_salary".
#
#
# Column aliases can be very useful for improving the readability of SQL code, especially when working with complex queries or when the original column names are too long or difficult to understand.

# %%
# %%sql
#
# SELECT COUNT(*) as total_records FROM employees
#
# ;
# Out:
# 1 rows affected.
# [(300024,)]

# %% [markdown]
# ## **`GROUP BY`**:
# The **`GROUP BY`** statement is used to group the result set by one or more columns. It is used with aggregate functions to group the data and calculate summary statistics.
#
# For example, to group the employees table by the gender column and count the number of employees in each group, you can use the following SQL statement:

# %%
# %%sql
#
# SELECT gender, COUNT(emp_no) as total_emp
# FROM employees
# GROUP BY gender
#
# limit 10
# ;
# Out:
# 2 rows affected.
# [('M', 179973), ('F', 120051)]

# %% [markdown]
# <img src="https://user-images.githubusercontent.com/60250009/226026520-6d25d1d9-d65d-448e-9a1e-3d5db0b5cf71.png" alt="Drawing" style="width: 600px;"/>

# %% [markdown]
# **Question**
# - Count the number of emloyees on a year of birth level
#
#
#
# **Hint**
# - **`"YEAR"`** is a function in MySQL which extracts year from a given date, Eg: YEAR('1953-09-02') = 1953

# %%
# %%sql
#
# SELECT year(birth_date) as year_of_birth, COUNT(emp_no) as total_emp
# FROM employees
# GROUP BY year(birth_date)
#
# ;
# Out:
# 14 rows affected.
# [(1953, 22857),
#  (1964, 22913),
#  (1959, 23311),
#  (1954, 23228),
#  (1955, 23104),
#  (1957, 22850),
#  (1958, 23276),
#  (1952, 21209),
#  (1963, 23080),
#  (1960, 23126),
#  (1956, 23051),
#  (1961, 23065),
#  (1962, 23014),
#  (1965, 1940)]

# %% [markdown]
# **Question**
# - Count the number of emloyees on a year of birth and gender level
#
#
#
# **Hint**
# - 2 level of group by is required

# %%
# %%sql
#
# SELECT year(birth_date) as year_of_birth,
#     gender,
#     COUNT(emp_no) as total_emp
# FROM employees
# GROUP BY year(birth_date), gender
#
# ;
# Out:
# 28 rows affected.
# [(1953, 'M', 13753),
#  (1964, 'F', 9045),
#  (1959, 'M', 14025),
#  (1954, 'M', 13843),
#  (1955, 'M', 13837),
#  (1953, 'F', 9104),
#  (1957, 'F', 9069),
#  (1958, 'M', 13964),
#  (1952, 'F', 8502),
#  (1963, 'F', 9194),
#  (1960, 'M', 13743),
#  (1963, 'M', 13886),
#  (1956, 'M', 13822),
#  (1961, 'M', 13796),
#  (1958, 'F', 9312),
#  (1954, 'F', 9385),
#  (1952, 'M', 12707),
#  (1962, 'F', 9216),
#  (1960, 'F', 9383),
#  (1962, 'M', 13798),
#  (1959, 'F', 9286),
#  (1956, 'F', 9229),
#  (1961, 'F', 9269),
#  (1957, 'M', 13781),
#  (1955, 'F', 9267),
#  (1964, 'M', 13868),
#  (1965, 'M', 1150),
#  (1965, 'F', 790)]

# %%
# %%sql
#
# SELECT year(birth_date) as year_of_birth,
#     gender,
#     COUNT(emp_no) as total_emp
# FROM employees
# GROUP BY 1,2
#
# ;
# Out:
# 28 rows affected.
# [(1953, 'M', 13753),
#  (1964, 'F', 9045),
#  (1959, 'M', 14025),
#  (1954, 'M', 13843),
#  (1955, 'M', 13837),
#  (1953, 'F', 9104),
#  (1957, 'F', 9069),
#  (1958, 'M', 13964),
#  (1952, 'F', 8502),
#  (1963, 'F', 9194),
#  (1960, 'M', 13743),
#  (1963, 'M', 13886),
#  (1956, 'M', 13822),
#  (1961, 'M', 13796),
#  (1958, 'F', 9312),
#  (1954, 'F', 9385),
#  (1952, 'M', 12707),
#  (1962, 'F', 9216),
#  (1960, 'F', 9383),
#  (1962, 'M', 13798),
#  (1959, 'F', 9286),
#  (1956, 'F', 9229),
#  (1961, 'F', 9269),
#  (1957, 'M', 13781),
#  (1955, 'F', 9267),
#  (1964, 'M', 13868),
#  (1965, 'M', 1150),
#  (1965, 'F', 790)]

# %%
# %%sql
#
# SELECT year(birth_date) as year_of_birth,
#     COUNT(emp_no) as total_emp
# FROM employees
# where gender = 'F'
# GROUP BY 1
#
# ;
# Out:
# 14 rows affected.
# [(1964, 9045),
#  (1953, 9104),
#  (1957, 9069),
#  (1952, 8502),
#  (1963, 9194),
#  (1958, 9312),
#  (1954, 9385),
#  (1962, 9216),
#  (1960, 9383),
#  (1959, 9286),
#  (1956, 9229),
#  (1961, 9269),
#  (1955, 9267),
#  (1965, 790)]

# %% [markdown]
# ## **`HAVING`**:
# The **`HAVING`** statement is used to filter the results of a GROUP BY query based on a specified condition. It is used to extract only the groups that meet the condition.
#
# For example, to group the **`employees`** table by the **`gender`** column and count the number of **`employees`** in each group, but only return groups with more than 100 employees, you can use the following SQL statement:

# %%
# %%sql
#
# SELECT year(birth_date) as year_of_birth,
#     COUNT(emp_no) as total_emp
# FROM employees
# where gender = 'F'
# GROUP BY 1
# having COUNT(emp_no) > 1000
#
# ;
# Out:
# 13 rows affected.
# [(1964, 9045),
#  (1953, 9104),
#  (1957, 9069),
#  (1952, 8502),
#  (1963, 9194),
#  (1958, 9312),
#  (1954, 9385),
#  (1962, 9216),
#  (1960, 9383),
#  (1959, 9286),
#  (1956, 9229),
#  (1961, 9269),
#  (1955, 9267)]

# %%
# %%sql
#
# SELECT gender, COUNT(*) FROM employees
# GROUP BY gender
# HAVING COUNT(*) > 100
#
# limit 10
# ;
# Out:
# 2 rows affected.
# [('M', 179973), ('F', 120051)]

# %% [markdown]
# **Question**
# - select all the `first_name` which has occured more than 300 times
#
#
#
#
# **Hint**
# - Use count(*) and HAVING clause

# %%
# %%sql
#
# SELECT first_name, count(*)
# FROM employees
# where first_name in ('Saniya', 'Bojan')
#  group by 1
#
# -- having count(*) > 250
# -- limit 100
# ;
# Out:
# 2 rows affected.
# [('Saniya', 257), ('Bojan', 263)]

# %% [markdown]
# ## ORDER BY:
# The **`ORDER`** BY statement is used to sort the result set by one or more columns in ascending or descending order.
#
# For example, to retrieve all columns from the **`employees`** table and sort them by the **`last_name`** column in ascending order, you can use the following SQL statement:

# %%
# %%sql
#
# SELECT * FROM employees
# ORDER BY last_name ASC
#
# limit 10
# ;
# Out:
# 10 rows affected.
# [(11761, datetime.date(1964, 7, 17), 'Bartek', 'Aamodt', 'M', datetime.date(1991, 6, 12)),
#  (15427, datetime.date(1959, 3, 6), 'Aluzio', 'Aamodt', 'M', datetime.date(1985, 3, 3)),
#  (18182, datetime.date(1963, 2, 23), 'Dekang', 'Aamodt', 'F', datetime.date(1988, 5, 25)),
#  (16572, datetime.date(1956, 11, 26), 'Matt', 'Aamodt', 'M', datetime.date(1987, 6, 16)),
#  (12791, datetime.date(1960, 6, 16), 'Mokhtar', 'Aamodt', 'M', datetime.date(1994, 8, 14)),
#  (12516, datetime.date(1958, 6, 25), 'Sreenivas', 'Aamodt', 'F', datetime.date(1990, 3, 6)),
#  (12982, datetime.date(1952, 12, 8), 'Sachem', 'Aamodt', 'F', datetime.date(1992, 1, 11)),
#  (17400, datetime.date(1962, 3, 22), 'Basim', 'Aamodt', 'F', datetime.date(1991, 9, 15)),
#  (19898, datetime.date(1957, 3, 9), 'Vidar', 'Aamodt', 'M', datetime.date(1988, 8, 6)),
#  (17885, datetime.date(1954, 2, 1), 'Takanari', 'Aamodt', 'M', datetime.date(1996, 8, 19))]

# %% [markdown]
# **Question**
# - Select distinct year of birth and gender from the `employees` table and order them
#
# **Hint**
# - **`"YEAR"`** is a function in MySQL which extracts year from a given date, Eg: YEAR('1953-09-02') = 1953

# %%
# %%sql
#
# select distinct year(birth_date), gender
# from employees
# order by 1,2
# ;
# Out:
# 28 rows affected.
# [(1952, 'M'),
#  (1952, 'F'),
#  (1953, 'M'),
#  (1953, 'F'),
#  (1954, 'M'),
#  (1954, 'F'),
#  (1955, 'M'),
#  (1955, 'F'),
#  (1956, 'M'),
#  (1956, 'F'),
#  (1957, 'M'),
#  (1957, 'F'),
#  (1958, 'M'),
#  (1958, 'F'),
#  (1959, 'M'),
#  (1959, 'F'),
#  (1960, 'M'),
#  (1960, 'F'),
#  (1961, 'M'),
#  (1961, 'F'),
#  (1962, 'M'),
#  (1962, 'F'),
#  (1963, 'M'),
#  (1963, 'F'),
#  (1964, 'M'),
#  (1964, 'F'),
#  (1965, 'M'),
#  (1965, 'F')]

# %% [markdown]
# **Question**
# - select all the `first_name` and the number of times they've occured sort them from the largest to smallest in occurance
#
#
#
#
# **Hint**
# - Use count(*) and `OORDER BY` clause

# %%
# %%sql
#
# SELECT first_name, count(*)
# FROM employees
# group by 1
# order by 2 desc
# limit 10
# ;
# Out:
# 10 rows affected.
# [('Shahab', 295),
#  ('Tetsushi', 291),
#  ('Elgin', 279),
#  ('Anyuan', 278),
#  ('Huican', 276),
#  ('Make', 275),
#  ('Sreekrishna', 272),
#  ('Panayotis', 272),
#  ('Hatem', 271),
#  ('Vitali', 270)]

# %% [markdown]
# ## CASE WHEN
# The CASE WHEN statement is a conditional expression that returns a value based on a condition. It is used to perform IF-THEN-ELSE logic in SQL. The syntax of the CASE WHEN statement is:

# %%
# SELECT
#     column_name,
#     CASE
#         WHEN condition1 THEN result1
#         WHEN condition2 THEN result2
#         ELSE result3
#     END
# FROM table_name;

# %% [markdown]
# Here's an example of using the CASE WHEN statement to create a new column in the employees table based on the gender of the employee:

# %%
# %%sql
# SELECT emp_no, first_name, last_name, gender,
#     CASE
#         WHEN gender = 'M' THEN 'Male'
#         WHEN gender = 'F' THEN 'Female'
#         ELSE 'Unknown'
#     END AS gender_full
# FROM employees
#
# LIMIT 10
# ;
# Out:
# 10 rows affected.
# [(10001, 'Georgi', 'Facello', 'M', 'Male'),
#  (10002, 'Bezalel', 'Simmel', 'F', 'Unknown'),
#  (10003, 'Parto', 'Bamford', 'M', 'Male'),
#  (10004, 'Chirstian', 'Koblick', 'M', 'Male'),
#  (10005, 'Kyoichi', 'Maliniak', 'M', 'Male'),
#  (10006, 'Anneke', 'Preusig', 'F', 'Unknown'),
#  (10007, 'Tzvetan', 'Zielinski', 'F', 'Unknown'),
#  (10008, 'Saniya', 'Kalloufi', 'M', 'Male'),
#  (10009, 'Sumant', 'Peac', 'F', 'Unknown'),
#  (10010, 'Duangkaew', 'Piveteau', 'F', 'Unknown')]

# %% [markdown]
# **Question**
# - Find out the number of employees born after or in 1965 and before 1965
#
# **Hint**
# - **`"YEAR"`** is a function in MySQL which extracts year from a given date, Eg: YEAR('1953-09-02') = 1953
# - Use `CASE WHEN` and Aggregation together

# %%
# %%sql
# SELECT count(emp_no) as emp_count,
#     case when year(birth_date) >= 1965 then 'Young People'
#     when year(birth_date) < 1965 then 'Senior People'
#     else 'Others' end as Year_bucket
# FROM employees
# group by Year_bucket
# LIMIT 100
# ;
# Out:
# 2 rows affected.
# [(298084, 'Senior People'), (1940, 'Young People')]

# %% [markdown]
# # Pivoting using **`CASE WHEN`**
#
# - Try to get the below output

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
# %%sql
#
# SELECT
#     year(birth_date) as year_of_birth,
#     sum(case when gender = 'M' then 1 else 0 end) as male_emp,
#     sum(case when gender = 'F' then 1 else 0 end) as female_emp
# FROM employees
# GROUP BY 1
# order by 1
# limit 50
# ;
# Out:
# 14 rows affected.
# [(1952, Decimal('12707'), Decimal('8502')),
#  (1953, Decimal('13753'), Decimal('9104')),
#  (1954, Decimal('13843'), Decimal('9385')),
#  (1955, Decimal('13837'), Decimal('9267')),
#  (1956, Decimal('13822'), Decimal('9229')),
#  (1957, Decimal('13781'), Decimal('9069')),
#  (1958, Decimal('13964'), Decimal('9312')),
#  (1959, Decimal('14025'), Decimal('9286')),
#  (1960, Decimal('13743'), Decimal('9383')),
#  (1961, Decimal('13796'), Decimal('9269')),
#  (1962, Decimal('13798'), Decimal('9216')),
#  (1963, Decimal('13886'), Decimal('9194')),
#  (1964, Decimal('13868'), Decimal('9045')),
#  (1965, Decimal('1150'), Decimal('790'))]

# %% [markdown]
# # JOINS
# Joins are used to combine data from two or more tables based on a related column between them. We will use *student* table along with *score* table to explain joins <br>
# **Note:** 'score' table contains student id and exam score of three subjects. It only contains score of students who have appeared for the exam

# %% [markdown]
# <img src="https://user-images.githubusercontent.com/60250009/226022487-e6dbd30b-d373-4662-b893-3f6c22e2fe7e.png" alt="Drawing" style="width: 800px;"/>

# %%
# employees [emp_no,birth_date,first_name,last_name,gender,hire_date]
# titles [emp_no,title,from_date,to_date]
# salaries [emp_no,salary,from_date,to_date]

# %% [markdown]
# <img src="https://user-images.githubusercontent.com/60250009/226027038-35ddf71c-b268-450e-9d96-489f2117e71c.png" alt="Drawing" style="width: 700px;"/>

# %%
# SELECT column_name(s)
# FROM table1
# JOIN table2
# ON table1.column_name = table2.column_name;

# %% [markdown]
# ## INNER JOIN
# The INNER JOIN is used to return only the rows in both tables that satisfy the join condition. For example, to select all students from the "student" table and their corresponding scores from the "score" table, you can use the following SQL code:

# %%
# %%sql
# SELECT employees.emp_no, employees.first_name, employees.last_name, titles.title
# FROM employees
# INNER JOIN titles
# ON employees.emp_no = titles.emp_no
# limit 10;
# Out:
# 10 rows affected.
# [(10001, 'Georgi', 'Facello', 'Senior Engineer'),
#  (10002, 'Bezalel', 'Simmel', 'Staff'),
#  (10003, 'Parto', 'Bamford', 'Senior Engineer'),
#  (10004, 'Chirstian', 'Koblick', 'Engineer'),
#  (10004, 'Chirstian', 'Koblick', 'Senior Engineer'),
#  (10005, 'Kyoichi', 'Maliniak', 'Senior Staff'),
#  (10005, 'Kyoichi', 'Maliniak', 'Staff'),
#  (10006, 'Anneke', 'Preusig', 'Senior Engineer'),
#  (10007, 'Tzvetan', 'Zielinski', 'Senior Staff'),
#  (10007, 'Tzvetan', 'Zielinski', 'Staff')]

# %% [markdown]
# ## LEFT JOIN
# The LEFT JOIN returns all the rows from the left table (employees), along with the matching rows from the right table (titles). If there are no matching rows in the right table, it returns NULL. Here's an example of a LEFT JOIN between the employees and titles tables on emp_no:

# %%
# %%sql
#
# SELECT E.*, d.dept_no, d.from_date, d.to_date
# FROM employees.employees e
# LEFT JOIN employees.dept_manager d
# ON e.emp_no = d.emp_no
# where e.emp_no in (110022,10003,110386,110228,10007,110085,10009)
#
# LIMIT 100
# ;
# Out:
# 7 rows affected.
# [(10003, datetime.date(1959, 12, 3), 'Parto', 'Bamford', 'M', datetime.date(1986, 8, 28), None, None, None),
#  (10007, datetime.date(1957, 5, 23), 'Tzvetan', 'Zielinski', 'F', datetime.date(1989, 2, 10), None, None, None),
#  (10009, datetime.date(1952, 4, 19), 'Sumant', 'Peac', 'F', datetime.date(1985, 2, 18), None, None, None),
#  (110022, datetime.date(1956, 9, 12), 'Margareta', 'Markovitch', 'M', datetime.date(1985, 1, 1), 'd001', datetime.date(1985, 1, 1), datetime.date(1991, 10, 1)),
#  (110085, datetime.date(1959, 10, 28), 'Ebru', 'Alpin', 'M', datetime.date(1985, 1, 1), 'd002', datetime.date(1985, 1, 1), datetime.date(1989, 12, 17)),
#  (110228, datetime.date(1958, 12, 2), 'Karsten', 'Sigstam', 'F', datetime.date(1985, 8, 4), 'd003', datetime.date(1992, 3, 21), datetime.date(9999, 1, 1)),
#  (110386, datetime.date(1953, 10, 4), 'Shem', 'Kieras', 'M', datetime.date(1988, 10, 14), 'd004', datetime.date(1992, 8, 2), datetime.date(1996, 8, 30))]

# %%
# %%sql
#
# SELECT E.*, d.dept_no, d.from_date, d.to_date
# FROM employees.employees e
# LEFT JOIN employees.dept_manager d
# ON e.emp_no = d.emp_no
# where e.emp_no in (110022,10003,110386,110228,10007,110085,10009)
#
#
# LIMIT 10
# ;
# Out:
# 7 rows affected.
# [(10003, datetime.date(1959, 12, 3), 'Parto', 'Bamford', 'M', datetime.date(1986, 8, 28), None, None, None),
#  (10007, datetime.date(1957, 5, 23), 'Tzvetan', 'Zielinski', 'F', datetime.date(1989, 2, 10), None, None, None),
#  (10009, datetime.date(1952, 4, 19), 'Sumant', 'Peac', 'F', datetime.date(1985, 2, 18), None, None, None),
#  (110022, datetime.date(1956, 9, 12), 'Margareta', 'Markovitch', 'M', datetime.date(1985, 1, 1), 'd001', datetime.date(1985, 1, 1), datetime.date(1991, 10, 1)),
#  (110085, datetime.date(1959, 10, 28), 'Ebru', 'Alpin', 'M', datetime.date(1985, 1, 1), 'd002', datetime.date(1985, 1, 1), datetime.date(1989, 12, 17)),
#  (110228, datetime.date(1958, 12, 2), 'Karsten', 'Sigstam', 'F', datetime.date(1985, 8, 4), 'd003', datetime.date(1992, 3, 21), datetime.date(9999, 1, 1)),
#  (110386, datetime.date(1953, 10, 4), 'Shem', 'Kieras', 'M', datetime.date(1988, 10, 14), 'd004', datetime.date(1992, 8, 2), datetime.date(1996, 8, 30))]

# %% [markdown]
# ## RIGHT JOIN
# The RIGHT JOIN returns all the rows from the right table (titles), along with the matching rows from the left table (employees). If there are no matching rows in the left table, it returns NULL. Here's an example of a RIGHT JOIN between the employees and titles tables on emp_no:

# %%
# %%sql
# SELECT E.*, d.dept_no, d.from_date, d.to_date
# FROM employees.dept_manager d
# RIGHT JOIN employees.employees e
# ON e.emp_no = d.emp_no
# where e.emp_no in (110022,10003,110386,110228,10007,110085,10009)
# LIMIT 100
# ;
# Out:
# 7 rows affected.
# [(10003, datetime.date(1959, 12, 3), 'Parto', 'Bamford', 'M', datetime.date(1986, 8, 28), None, None, None),
#  (10007, datetime.date(1957, 5, 23), 'Tzvetan', 'Zielinski', 'F', datetime.date(1989, 2, 10), None, None, None),
#  (10009, datetime.date(1952, 4, 19), 'Sumant', 'Peac', 'F', datetime.date(1985, 2, 18), None, None, None),
#  (110022, datetime.date(1956, 9, 12), 'Margareta', 'Markovitch', 'M', datetime.date(1985, 1, 1), 'd001', datetime.date(1985, 1, 1), datetime.date(1991, 10, 1)),
#  (110085, datetime.date(1959, 10, 28), 'Ebru', 'Alpin', 'M', datetime.date(1985, 1, 1), 'd002', datetime.date(1985, 1, 1), datetime.date(1989, 12, 17)),
#  (110228, datetime.date(1958, 12, 2), 'Karsten', 'Sigstam', 'F', datetime.date(1985, 8, 4), 'd003', datetime.date(1992, 3, 21), datetime.date(9999, 1, 1)),
#  (110386, datetime.date(1953, 10, 4), 'Shem', 'Kieras', 'M', datetime.date(1988, 10, 14), 'd004', datetime.date(1992, 8, 2), datetime.date(1996, 8, 30))]

# %% [markdown]
# ## OUTER JOIN
# An OUTER JOIN returns all the rows from both tables, along with the matching rows based on the join condition. If there is no match, NULL is returned for the missing values

# %%
# %%sql
# SELECT employees.emp_no, employees.first_name, employees.last_name, titles.title
# FROM employees
# OUTER JOIN titles
# ON employees.emp_no = titles.emp_no
# LIMIT 10;
# Out:
# 10 rows affected.
# [(10001, 'Georgi', 'Facello', 'Senior Engineer'),
#  (10002, 'Bezalel', 'Simmel', 'Staff'),
#  (10003, 'Parto', 'Bamford', 'Senior Engineer'),
#  (10004, 'Chirstian', 'Koblick', 'Engineer'),
#  (10004, 'Chirstian', 'Koblick', 'Senior Engineer'),
#  (10005, 'Kyoichi', 'Maliniak', 'Senior Staff'),
#  (10005, 'Kyoichi', 'Maliniak', 'Staff'),
#  (10006, 'Anneke', 'Preusig', 'Senior Engineer'),
#  (10007, 'Tzvetan', 'Zielinski', 'Senior Staff'),
#  (10007, 'Tzvetan', 'Zielinski', 'Staff')]

# %% [markdown]
# ## Window Functions
# Window Functions: Window functions are a type of SQL function that perform calculations across a set of rows that are related to the current row. They are used to compute values that are based on a subset of rows in the result set. Some common window functions include RANK, ROW_NUMBER, and DENSE_RANK.
# - **`ROW_NUMBER:`** The ROW_NUMBER function assigns a unique number to each row in the result set. The numbering starts at 1 for the first row and increments by 1 for each subsequent row. Here's an example of using the ROW_NUMBER function to rank employees based on their hire date:

# %%
# %%sql
# SELECT emp_no, first_name, last_name, hire_date,
#        ROW_NUMBER() OVER(ORDER BY hire_date desc) AS hire_rank
# FROM employees
# LIMIT 10;
# Out:
# 10 rows affected.
# [(463807, 'Bikash', 'Covnot', datetime.date(2000, 1, 28), 1),
#  (428377, 'Yucai', 'Gerlach', datetime.date(2000, 1, 23), 2),
#  (499553, 'Hideyuki', 'Delgrande', datetime.date(2000, 1, 22), 3),
#  (222965, 'Volkmar', 'Perko', datetime.date(2000, 1, 13), 4),
#  (47291, 'Ulf', 'Flexer', datetime.date(2000, 1, 12), 5),
#  (422990, 'Jaana', 'Verspoor', datetime.date(2000, 1, 11), 6),
#  (227544, 'Shahab', 'Demeyer', datetime.date(2000, 1, 8), 7),
#  (205048, 'Ennio', 'Alblas', datetime.date(2000, 1, 6), 8),
#  (226633, 'Xuejun', 'Benzmuller', datetime.date(2000, 1, 4), 9),
#  (424445, 'Jeong', 'Boreale', datetime.date(2000, 1, 3), 10)]

# %% [markdown]
# - **`RANK:`** The RANK function assigns a rank to each row in the result set based on the value of a specified column. If two or more rows have the same value, they are assigned the same rank, and the next rank is skipped. Here's an example of using the RANK function to rank employees based on their salary:

# %%
# %%sql
# SELECT emp_no, first_name, last_name, hire_date,  year(hire_date),
#        ROW_NUMBER() OVER(ORDER BY year(hire_date) desc) AS hire_rank
# FROM employees
# LIMIT 10;
# Out:
# 10 rows affected.
# [(499553, 'Hideyuki', 'Delgrande', datetime.date(2000, 1, 22), 2000, 1),
#  (463807, 'Bikash', 'Covnot', datetime.date(2000, 1, 28), 2000, 2),
#  (205048, 'Ennio', 'Alblas', datetime.date(2000, 1, 6), 2000, 3),
#  (108201, 'Mariangiola', 'Boreale', datetime.date(2000, 1, 1), 2000, 4),
#  (47291, 'Ulf', 'Flexer', datetime.date(2000, 1, 12), 2000, 5),
#  (428377, 'Yucai', 'Gerlach', datetime.date(2000, 1, 23), 2000, 6),
#  (422990, 'Jaana', 'Verspoor', datetime.date(2000, 1, 11), 2000, 7),
#  (424445, 'Jeong', 'Boreale', datetime.date(2000, 1, 3), 2000, 8),
#  (72329, 'Randi', 'Luit', datetime.date(2000, 1, 2), 2000, 9),
#  (60134, 'Seshu', 'Rathonyi', datetime.date(2000, 1, 2), 2000, 10)]

# %%
# %%sql
# SELECT emp_no, first_name, last_name, hire_date,  year(hire_date),
#        RANK() OVER(ORDER BY year(hire_date) desc) AS hire_rank
# FROM employees
# LIMIT 100;
# Out:
# 100 rows affected.
# [(499553, 'Hideyuki', 'Delgrande', datetime.date(2000, 1, 22), 2000, 1),
#  (463807, 'Bikash', 'Covnot', datetime.date(2000, 1, 28), 2000, 1),
#  (205048, 'Ennio', 'Alblas', datetime.date(2000, 1, 6), 2000, 1),
#  (108201, 'Mariangiola', 'Boreale', datetime.date(2000, 1, 1), 2000, 1),
#  (47291, 'Ulf', 'Flexer', datetime.date(2000, 1, 12), 2000, 1),
#  (428377, 'Yucai', 'Gerlach', datetime.date(2000, 1, 23), 2000, 1),
#  (422990, 'Jaana', 'Verspoor', datetime.date(2000, 1, 11), 2000, 1),
#  (424445, 'Jeong', 'Boreale', datetime.date(2000, 1, 3), 2000, 1),
#  (72329, 'Randi', 'Luit', datetime.date(2000, 1, 2), 2000, 1),
#  (60134, 'Seshu', 'Rathonyi', datetime.date(2000, 1, 2), 2000, 1),
#  (222965, 'Volkmar', 'Perko', datetime.date(2000, 1, 13), 2000, 1),
#  (226633, 'Xuejun', 'Benzmuller', datetime.date(2000, 1, 4), 2000, 1),
#  (227544, 'Shahab', 'Demeyer', datetime.date(2000, 1, 8), 2000, 1),
# ...

# %% [markdown]
# - **`DENSE_RANK:`** The DENSE_RANK function assigns a rank to each row in the result set based on the value of a specified column. If two or more rows have the same value, they are assigned the same rank, and the next rank is not skipped. Here's an example of using the DENSE_RANK function to rank employees based on their salary:

# %%
# %%sql
# SELECT emp_no, first_name, last_name, hire_date,  year(hire_date),
#        DENSE_RANK() OVER(ORDER BY year(hire_date) desc) AS hire_rank
# FROM employees
# LIMIT 100;
# Out:
# 100 rows affected.
# [(499553, 'Hideyuki', 'Delgrande', datetime.date(2000, 1, 22), 2000, 1),
#  (463807, 'Bikash', 'Covnot', datetime.date(2000, 1, 28), 2000, 1),
#  (205048, 'Ennio', 'Alblas', datetime.date(2000, 1, 6), 2000, 1),
#  (108201, 'Mariangiola', 'Boreale', datetime.date(2000, 1, 1), 2000, 1),
#  (47291, 'Ulf', 'Flexer', datetime.date(2000, 1, 12), 2000, 1),
#  (428377, 'Yucai', 'Gerlach', datetime.date(2000, 1, 23), 2000, 1),
#  (422990, 'Jaana', 'Verspoor', datetime.date(2000, 1, 11), 2000, 1),
#  (424445, 'Jeong', 'Boreale', datetime.date(2000, 1, 3), 2000, 1),
#  (72329, 'Randi', 'Luit', datetime.date(2000, 1, 2), 2000, 1),
#  (60134, 'Seshu', 'Rathonyi', datetime.date(2000, 1, 2), 2000, 1),
#  (222965, 'Volkmar', 'Perko', datetime.date(2000, 1, 13), 2000, 1),
#  (226633, 'Xuejun', 'Benzmuller', datetime.date(2000, 1, 4), 2000, 1),
#  (227544, 'Shahab', 'Demeyer', datetime.date(2000, 1, 8), 2000, 1),
# ...

# %%
# %%sql
# SELECT emp_no, salary,
#        DENSE_RANK() OVER(ORDER BY salary DESC) AS salary_rank
# FROM salaries
# LIMIT 10;
# Out:
# 10 rows affected.
# [(43624, 158220, 1),
#  (43624, 157821, 2),
#  (47978, 155709, 3),
#  (109334, 155377, 4),
#  (109334, 155190, 5),
#  (109334, 154888, 6),
#  (109334, 154885, 7),
#  (80823, 154459, 8),
#  (43624, 153458, 9),
#  (43624, 153166, 10)]
