# %% [markdown]
# ![image.png](attachment:image.png)[Follow Us](https://www.linkedin.com/company/analytics-school/?viewAsMember=true)

# %%
# %load_ext sql
# %reload_ext sql
import pymysql
import urllib.parse

# %%
password = urllib.parse.quote_plus('Mukul@ms30')

# %sql mysql+pymysql://root:{password}@localhost/mavenfuzzyfactory

# %config SqlMagic.displaycon = False
# Out:
# /Users/anand/opt/anaconda3/lib/python3.9/site-packages/IPython/core/interactiveshell.py:3444: UserWarning: Config option `displaycon` not recognized by `SqlMagic`.  Did you mean `displaylimit`?
#   exec(code_obj, self.user_global_ns, self.user_ns)
